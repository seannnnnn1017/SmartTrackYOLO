# %% [markdown]
# # Get Data

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Q5qZgvS8HpWWVRDEzQ2s")
project = rf.workspace("university-of-heidelberg").project("box-object-detection-2")
version = project.version(4)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Box-object-detection-2-4 in yolov5pytorch:: 100%|██████████| 1578/1578 [00:00<00:00, 2355.38it/s]

# %%
import shutil # Move the dataset

# %%
shutil.move('Box-object-detection-2-4/train',
'Box-object-detection-2-4/Box-object-detection-2-4/train')

shutil.move('Box-object-detection-2-4/test',
'Box-object-detection-2-4/Box-object-detection-2-4/test')

shutil.move('Box-object-detection-2-4/valid',
'Box-object-detection-2-4/Box-object-detection-2-4/valid')
# Out:
# 'Box-object-detection-2-4/Box-object-detection-2-4/valid'

# %%
# !yolo task=detect  mode=train model=yolov5l6u.pt data=C:/Users/fishd/Desktop/Github/SmartTrackYOLO/training/Box-object-detection-2-4/data.yaml epochs=100 imgsz=640 batch=16 amp=True workers=8
# Out:
# Ultralytics YOLOv8.2.45 🚀 Python-3.11.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 16376MiB)
# ...

# %%
import torch
torch.cuda.empty_cache()

# %%
import os
from ultralytics import YOLO
import torch
torch.cuda.empty_cache()
# 確保已安裝最新版本的 ultralytics
os.system('pip install -U ultralytics')

# 設置模型和數據集路徑
model_path = 'models/yolov5l6.pt'
data_path = 'C:/Users/fishd/Desktop/Github/SmartTrackYOLO/training/Box-object-detection-2-4/data.yaml'

# 訓練參數
epochs = 100
imgsz = 640

# 加載模型
model = YOLO(model_path)

# 開始訓練
model.train(
    data=data_path,
    epochs=epochs,
    imgsz=imgsz,
    project='runs/train',  # 設置訓練結果保存路徑
    name='exp',  # 設置訓練結果保存的實驗名稱
    device=0,  # 設置訓練設備，例如 '0' 表示使用第一塊 GPU，'0,1,2,3' 表示使用多塊 GPU
    batch=32,  # 設置批次大小
    workers=8,  # 設置工作線程數
    save_period=-1,  # 設置保存模型的週期
    pretrained=True,  # 使用預訓練模型
    optimizer='auto',  # 自動選擇優化器
    verbose=True,  # 啟用詳細日誌
    seed=0,  # 設置隨機種子
    deterministic=True,  # 確保結果可重現
    amp=True  # 啟用自動混合精度
)
# Out:
# PRO TIP  Replace 'model=models/yolov5l6.pt' with new 'model=models/yolov5l6u.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics YOLOv8.2.45  Python-3.11.0 torch-2.3.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 16376MiB)
# ...
